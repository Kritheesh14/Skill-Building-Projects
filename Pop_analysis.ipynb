# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
import sys

# %%
#data
years=list(i for i in range(2000,2026))
pops=[1059633675, 1078970907, 1098313039, 1117415123, 1136264583, 1154638713, 1172373788, 1189691809, 1206734806, 1223640160, 1240613620, 1257621191, 1274487215, 1291132063, 1307246509, 1322866505, 1338636340, 1354195680, 1369003306, 1383112050, 1396387127, 1407563842, 1417173173, 1428627663,1441719852,1454606724]

# %%
def pop_overall():
    dat = pd.DataFrame({"Year":years ,"Population":pops})
    df = pd.DataFrame(dat)
    x = df[['Year']]
    y = df[['Population']]

    xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=0)
    model=LinearRegression()
    model.fit(xtrain, ytrain)

    predictiony=model.predict(xtest)

    warnings.filterwarnings("ignore", category=UserWarning, message="X does not have valid feature names")

    newval = int(input("Enter the year to predict the population at that time: "))
    if newval <= 2025:
        sys.exit()
    predv = model.predict([[newval]])
    pred = predv[0][0]

    output = f"The predicted value for {newval} is: {pred:.2f}"
    print(output)

    plt.figure(figsize=(10,8))
    plt.scatter(x, y, label='Original Data', color='green', alpha=0.5)
    plt.scatter(xtest, ytest, label='Test Data', color='blue', alpha=0.3)
    plt.scatter(newval, pred, label='Predicted Population (New Year)', color='red', marker='*', s=100)
    plt.xlabel('Year')
    plt.ylabel('Population')    
    plt.title('Population Prediction!')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.xlim
    plt.xlim(1995,newval+5)
    plt.ylim(min(df['Population'])*.8, max(df['Population'])*1.2)
    plt.show()
def birthrate():
    br=[26.635]

# %%
pop_overall()
# Out:
# The predicted value for 2026 is: 1485951499.03
